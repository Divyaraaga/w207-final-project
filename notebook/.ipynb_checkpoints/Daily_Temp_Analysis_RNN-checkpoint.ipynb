# %% [markdown]
# # Time Series to observe DAILY temperature variations
# ## Daily temperature prediction using RNN

# %% [markdown]
# Moving from predictive Machine Learning classifier to Unpredicitve Neural Nets, we use Sequential ** Recurrent Neural Net (RNN)** in the notebook below.
#
# You need to ensure that you have the right environment installed on top of your python3 to run Keras and Tensorflow. Two libraries needed to successfully run (RNN).
#
# Just like in the other models, we begin by loading all necessary libraries and paths to read the "pickles" as well as store image for the graph towards the end of our code. The pickles are read and the data is fed into an RNN model.
# Finally, we have two graphs showing the DT results vs. the fitted model as well as predicted results vs. actuals and test data

# %% [markdown]
# Here we are importing the train and test Data from pickle files created through the EDA file

# %%
# %run helper_functions.py
# %matplotlib inline
# Out:
# /anaconda3/lib/python3.6/site-packages/plotly/graph_objs/_deprecations.py:558: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis
#
#
# /anaconda3/lib/python3.6/site-packages/plotly/graph_objs/_deprecations.py:531: DeprecationWarning:
#
# plotly.graph_objs.XAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.XAxis
#   - plotly.graph_objs.layout.scene.XAxis
#
#
# Using TensorFlow backend.
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning:
#
# The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Create a folder for every run of the RNN to store images

# %%
IMAGE_DIR = create_results_perrun()
print("Path of the results Image directory",IMAGE_DIR )
# Out:
# Path of the results Image directory ../Images/RESULTS/RUN-9

# %%
city='Los_Angeles'
X_train = pd.read_pickle(f'{PICKLE_PATH}/X_train_{city}.pkl')
Y_train = pd.read_pickle(f'{PICKLE_PATH}/Y_train_{city}.pkl')

X_test  = pd.read_pickle(f'{PICKLE_PATH}/X_test_{city}.pkl')
Y_test  = pd.read_pickle(f'{PICKLE_PATH}/Y_test_{city}.pkl')

print("Shape of Training Dataset " , X_train.shape)
print("Shape of Testing Dataset " , X_test.shape)
# Out:
# Shape of Training Dataset  (1432, 31)
# Shape of Testing Dataset  (90, 31)

# %%
# Function to fit a sequential rnn with loss estimate being mean squared error
def train_model(X_train, y_train, X_test, y_test, epochs):
    model = Sequential(
        [
            Dense(10, activation="relu", input_shape=(X_train.shape[1],)),
            Dense(10, activation="relu"),
            Dense(10, activation="relu"),
            Dense(1, activation="linear")
        ]
    )
    model.compile(optimizer=Adam(lr=0.001), loss="mean_squared_error")
    
    history = model.fit(X_train, y_train, epochs=epochs, shuffle=False)
    return model, history

# %%
# Function to fit a sequential rnn with epochs = 50
epochs = 50
model_encoded, encoded_hist = train_model(
    X_train,
    Y_train,
    X_test,
    Y_test,
    epochs=epochs
)
# Out:
# Epoch 1/50
# 1432/1432 [==============================] - 0s 187us/step - loss: 256.6088
# Epoch 2/50
# 1432/1432 [==============================] - 0s 24us/step - loss: 108.4048
# Epoch 3/50
# 1432/1432 [==============================] - 0s 24us/step - loss: 11.4362
# Epoch 4/50
# 1432/1432 [==============================] - 0s 26us/step - loss: 5.4402
# Epoch 5/50
# 1432/1432 [==============================] - 0s 25us/step - loss: 5.0984
# Epoch 6/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 4.2989
# Epoch 7/50
# 1432/1432 [==============================] - 0s 25us/step - loss: 3.9713
# Epoch 8/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 3.7077
# Epoch 9/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 3.4630
# Epoch 10/50
# 1432/1432 [==============================] - 0s 22us/step - loss: 3.2733
# Epoch 11/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 3.1237
# Epoch 12/50
# 1432/1432 [==============================] - 0s 27us/step - loss: 3.0182
# Epoch 13/50
# 1432/1432 [==============================] - 0s 27us/step - loss: 2.9283
# Epoch 14/50
# 1432/1432 [==============================] - 0s 28us/step - loss: 2.8474
# Epoch 15/50
# 1432/1432 [==============================] - 0s 26us/step - loss: 2.7746
# Epoch 16/50
# 1432/1432 [==============================] - 0s 29us/step - loss: 2.7056
# Epoch 17/50
# 1432/1432 [==============================] - 0s 27us/step - loss: 2.6456
# Epoch 18/50
# 1432/1432 [==============================] - 0s 26us/step - loss: 2.5914
# Epoch 19/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 2.5457
# Epoch 20/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 2.5057
# Epoch 21/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 2.4680
# Epoch 22/50
# 1432/1432 [==============================] - 0s 25us/step - loss: 2.4340
# Epoch 23/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 2.4024
# Epoch 24/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 2.3709
# Epoch 25/50
# 1432/1432 [==============================] - 0s 22us/step - loss: 2.3331
# Epoch 26/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 2.2789
# Epoch 27/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 2.2230
# Epoch 28/50
# 1432/1432 [==============================] - 0s 22us/step - loss: 2.1935
# Epoch 29/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 2.1795
# Epoch 30/50
# 1432/1432 [==============================] - 0s 22us/step - loss: 2.1578
# Epoch 31/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 2.1126
# Epoch 32/50
# 1432/1432 [==============================] - 0s 26us/step - loss: 2.0518
# Epoch 33/50
# 1432/1432 [==============================] - 0s 27us/step - loss: 1.9876
# Epoch 34/50
# 1432/1432 [==============================] - 0s 24us/step - loss: 1.9320
# Epoch 35/50
# 1432/1432 [==============================] - 0s 24us/step - loss: 1.8855
# Epoch 36/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 1.8500
# Epoch 37/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 1.8278
# Epoch 38/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 1.8433
# Epoch 39/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 1.9242
# Epoch 40/50
# 1432/1432 [==============================] - 0s 22us/step - loss: 2.1197
# Epoch 41/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 2.5680
# Epoch 42/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 3.2696
# Epoch 43/50
# 1432/1432 [==============================] - 0s 24us/step - loss: 3.2151
# Epoch 44/50
# 1432/1432 [==============================] - 0s 24us/step - loss: 2.2858
# Epoch 45/50
# 1432/1432 [==============================] - 0s 24us/step - loss: 1.7665
# Epoch 46/50
# 1432/1432 [==============================] - 0s 24us/step - loss: 1.6005
# Epoch 47/50
# 1432/1432 [==============================] - 0s 25us/step - loss: 1.5344
# Epoch 48/50
# 1432/1432 [==============================] - 0s 24us/step - loss: 1.4762
# Epoch 49/50
# 1432/1432 [==============================] - 0s 23us/step - loss: 1.4165
# Epoch 50/50
# 1432/1432 [==============================] - 0s 26us/step - loss: 1.3673

# %%
# Run the model on the training dataset
Y_train_pred = model_encoded.predict(X_train)
# Calculate mean squared error for the predicted values
mse_train = mean_squared_error(Y_train, model_encoded.predict(X_train))
print('Mean Squared Error for the training dataset: %.3f' % mse_train)
# Out:
# Mean Squared Error for the training dataset: 1.523

# %%
# Run the model on the testing dataset
Y_test_pred = model_encoded.predict(X_test)
# Calculate mean squared error for the test vs predicted values
mse_test = mean_squared_error(Y_test, model_encoded.predict(X_test))
print('Mean Squared Error for the testing dataset: %.3f' % mse_test)
# Out:
# Mean Squared Error for the testing dataset: 1.489

# %%
# Creating a dataframe for predicted/fitted values
future_forecast = pd.DataFrame(Y_test_pred,index = Y_test.index,columns=['Fitted'])

# Concatenate the predicted/fitted values with actual values to display graphs
predictions = pd.concat([Y_test,future_forecast],axis=1)
predictions.columns = ["Actual","Fitted"]

# Displaying few of the predicted values
predictions.head(10)
# Out:
#                Actual     Fitted
# datetime
# 2017-09-02  30.183750  29.157001
# 2017-09-03  30.973333  29.617113
# 2017-09-04  25.004167  28.380222
# 2017-09-05  23.995833  23.550476
# 2017-09-06  24.896250  23.983486
# 2017-09-07  23.748333  24.328583
# 2017-09-08  23.372500  23.079487
# 2017-09-09  22.320417  22.571083
# 2017-09-10  23.954583  22.331566
# 2017-09-11  25.469583  24.232861

# %%
city = city.replace('_',' ')
# Plotting the daily predicted temperature vs Actual Temperature - RNN
fig = charter_helper_fitted("Daily Predicted Temperature using RNN for " + city, predictions)
iplot(fig)
#py.image.save_as(fig, f'{IMAGE_DIR}/Daily_RNN_actual_vs_predict.png')
# Out:
# <div id="426bdd31-976a-4bed-b269-9976ac8220e4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plotly.att.com";
#         Plotly.plot(
#             '426bdd31-976a-4bed-b269-9976ac8220e4',
#             [{"name": "Actual", "x": ["2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-09-30", "2017-10-01", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-07", "2017-10-08", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-14", "2017-10-15", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-21", "2017-10-22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28", "2017-10-29", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-04", "2017-11-05", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-11", "2017-11-12", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-18", "2017-11-19", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-23", "2017-11-24", "2017-11-25", "2017-11-26", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30"], "y": [30.18375000000003, 30.97333333333336, 25.004166666666688, 23.995833333333355, 24.896250000000023, 23.748333333333353, 23.37250000000002, 22.320416666666688, 23.95458333333336, 25.469583333333357, 24.396250000000027, 21.991666666666685, 20.242500000000025, 20.469166666666684, 20.589166666666685, 20.495000000000022, 19.972083333333362, 20.90166666666669, 20.587916666666686, 20.36302033408335, 17.865416666666686, 17.929166666666685, 19.550833333333355, 22.068333333333346, 22.126250000000024, 21.56625000000002, 22.336215200458355, 23.20291666666669, 21.940416666666696, 20.47708333333335, 19.92958333333335, 19.558333333333355, 18.662916666666693, 19.957083333333355, 21.63833333333335, 23.93250000000002, 21.78458333333336, 20.796666666666688, 21.422083333333358, 19.823333333333352, 18.962500000000023, 18.592083333333353, 19.774250000000023, 23.15625000000001, 24.42666666666669, 24.522083333333356, 24.052916666666686, 21.145833333333353, 19.305000000000014, 18.504583333333354, 21.48000000000002, 25.885000000000023, 30.895833333333346, 30.146666666666686, 25.286250000000024, 22.307500000000022, 20.40916666666669, 18.636666666666688, 18.419166666666683, 18.123333333333353, 18.235000000000024, 17.611666666666686, 17.22666666666668, 17.179166666666685, 17.67875000000002, 17.07666666666668, 18.013333333333353, 18.15762108558335, 18.109012328500018, 16.946250000000017, 15.689988296208353, 15.853750000000018, 15.731666666666689, 16.654166666666686, 17.97034089854169, 19.003333333333355, 19.582083333333355, 17.352500000000017, 17.299583333333356, 15.820416666666686, 18.979583333333355, 22.37833333333336, 23.58916666666669, 21.030416666666685, 19.876666666666683, 17.274166666666687, 16.214583333333355, 14.36279166666669, 16.07708333333336, 21.78000000000003], "type": "scatter", "uid": "6a1b1246-9dc7-11e8-a22b-3c15c2df16f6"}, {"name": "Fitted", "x": ["2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-09-30", "2017-10-01", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-07", "2017-10-08", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-14", "2017-10-15", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-21", "2017-10-22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28", "2017-10-29", "2017-10-30", "20 ...
#             {"title": "Daily Predicted Temperature using RNN for Los Angeles", "xaxis": {"rangeselector": {"buttons": [{"step": "all"}, {"count": 1, "label": "1m", "step": "month", "stepmode": "backward"}]}, "rangeslider": {"visible": true}, "type": "date"}},
#             {"showLink": true, "linkText": "Export to plotly.att.com"}
#         ).then(function () {return Plotly.addFrames('426bdd31-976a-4bed-b269-9976ac8220e4',{});}).then(function(){Plotly.animate('426bdd31-976a-4bed-b269-9976ac8220e4');})
#         });</script>

# %%
 # Plotting the training data for past year, Actual/test data and predicted temperature - Decision Tree
fig = charter_helper_prediction("Daily Predicted Temperature using RNN for " + city, 
                     X_train,Y_train,X_test,Y_test,future_forecast)

iplot(fig)
#py.image.save_as(fig, f'{IMAGE_DIR}/Daily_RNN_predict.png')
# Out:
# <div id="d9c3fd46-d421-4588-8e0c-6116a0da4827" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plotly.att.com";
#         Plotly.plot(
#             'd9c3fd46-d421-4588-8e0c-6116a0da4827',
#             [{"name": "Train temperature", "x": ["2016-09-02", "2016-09-03", "2016-09-04", "2016-09-05", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-10", "2016-09-11", "2016-09-12", "2016-09-13", "2016-09-14", "2016-09-15", "2016-09-16", "2016-09-17", "2016-09-18", "2016-09-19", "2016-09-20", "2016-09-21", "2016-09-22", "2016-09-23", "2016-09-24", "2016-09-25", "2016-09-26", "2016-09-27", "2016-09-28", "2016-09-29", "2016-09-30", "2016-10-01", "2016-10-02", "2016-10-03", "2016-10-04", "2016-10-05", "2016-10-06", "2016-10-07", "2016-10-08", "2016-10-09", "2016-10-10", "2016-10-11", "2016-10-12", "2016-10-13", "2016-10-14", "2016-10-15", "2016-10-16", "2016-10-17", "2016-10-18", "2016-10-19", "2016-10-20", "2016-10-21", "2016-10-22", "2016-10-23", "2016-10-24", "2016-10-25", "2016-10-26", "2016-10-27", "2016-10-28", "2016-10-29", "2016-10-30", "2016-10-31", "2016-11-01", "2016-11-02", "2016-11-03", "2016-11-04", "2016-11-05", "2016-11-06", "2016-11-07", "2016-11-08", "2016-11-09", "2016-11-10", "2016-11-11", "2016-11-12", "2016-11-13", "2016-11-14", "2016-11-15", "2016-11-16", "2016-11-17", "2016-11-18", "2016-11-19", "2016-11-20", "2016-11-21", "2016-11-22", "2016-11-23", "2016-11-24", "2016-11-25", "2016-11-26", "2016-11-27", "2016-11-28", "2016-11-29", "2016-11-30", "2016-12-01", "2016-12-02", "2016-12-03", "2016-12-04", "2016-12-05", "2016-12-06", "2016-12-07", "2016-12-08", "2016-12-09", "2016-12-10", "2016-12-11", "2016-12-12", "2016-12-13", "2016-12-14", "2016-12-15", "2016-12-16", "2016-12-17", "2016-12-18", "2016-12-19", "2016-12-20", "2016-12-21", "2016-12-22", "2016-12-23", "2016-12-24", "2016-12-25", "2016-12-26", "2016-12-27", "2016-12-28", "2016-12-29", "2016-12-30", "2016-12-31", "2017-01-01", "2017-01-02", "2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-07", "2017-01-08", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-14", "2017-01-15", "2017-01-16", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-21", "2017-01-22", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-28", "2017-01-29", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-04", "2017-02-05", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-11", "2017-02-12", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-18", "2017-02-19", "2017-02-20", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-25", "2017-02-26", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-04", "2017-03-05", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-11", "2017-03-12", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-18", "2017-03-19", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-25", "2017-03-26", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-01", "2017-04-02", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-08", "2017-04-09", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-14", "2017-04-15", "2017-04-16", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-22", "2017-04-23", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-04-29", "2017-04-30", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-06", "2017-05-07", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-13", "2017-05-14", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-20", "2017-05-21", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-27", "2017-05-28", "2017-05-29", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-03", "2017-06-04", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-10", "20 ...

# %%
results = update_results_function('RNN',f'{city}',X_train._metadata["feature_set_type"],
                                  {'epochs': epochs,'Info': X_train._metadata}, 
                                  {'features' : X_train.columns.values.tolist(),
                                   'importances':'NA',
                                   'mse_train' : mse_train}, 
                                    mse_test) 
results
# Out:
#   RUN NO                   DATETIME     MODEL NAME         CITY HOST_MACHINE  \
# 0  RUN-1 2018-08-10 23:49:12.225283  DECISION TREE     New York  ELS-F25750M
# 1  RUN-2 2018-08-10 23:49:20.941142  RANDOM FOREST     New York  ELS-F25750M
# 2  RUN-3 2018-08-11 01:45:24.629820  DECISION TREE     New York  ELS-F25750M
# 3  RUN-4 2018-08-11 01:48:28.286225  DECISION TREE     New York  ELS-F25750M
# 4  RUN-5 2018-08-11 02:33:46.185720  DECISION TREE     New York  ELS-F25750M
# 5  RUN-6 2018-08-11 17:32:11.519405  DECISION TREE     New York  ELS-F25750M
# 6  RUN-7 2018-08-11 17:32:28.362016  DECISION TREE     New York  ELS-F25750M
# 7  RUN-8 2018-08-11 17:33:32.608016  RANDOM FOREST  Los Angeles  ELS-F25750M
# 8  RUN-9 2018-08-11 17:34:04.410385            RNN  Los Angeles  ELS-F25750M
#
#                                           PARAMETERS  \
# 0                                   {'max_depth': 8}
# 1               {'max_depth': 8, 'n_estimators': 50}
# 2  {'max_depth': 8, 'Info': <bound method DataFra...
# 3  {'max_depth': 8, 'Info': {'city': 'New_York', ...
# 4  {'max_depth': 8, 'Info': {'city': 'New York', ...
# 5  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 6  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 7  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 8  {'epochs': 50, 'Info': {'feature_set_type': 'E...
#
#                                              RESULTS  MEAN SQUARED ERROR  \
# 0  {'features': ['temperature_lag1', 'temperature...            0.517323
# 1  {'features': ['temperature_lag1', 'temperature...            0.321614
# 2  {'features': ['temperature_lag1', 'temperature...            0.558036
# 3  {'features': ['temperature_lag1', 'temperature...            0.532833
# 4  {'features': ['temperature_lag1', 'temperature...            0.528534
# 5  {'features': ['temperature_lag1', 'temperature...            0.560820
# 6  {'features': ['temperature_lag1', 'temperature...            0.541863
# 7  {'features': ['temperature_lag1', 'temperature...            0.365879
# 8  {'features': ['temperature_lag1', 'temperature...            1.489261
#
#         FEATURE_TYPE
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4
# 5  Enhanced Features
# 6  Enhanced Features
# 7  Enhanced Features
# 8  Enhanced Features
