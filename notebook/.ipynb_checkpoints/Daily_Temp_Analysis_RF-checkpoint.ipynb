# %% [markdown]
# # Time Series to observe DAILY temperature variations
# ## Daily temperature prediction using Random Forest

# %% [markdown]
# Going one step deeper than a tree, we use in the notebook below
#
# **Random Forests ** : We begin by loading all necessary libraries and paths to read the "pickles" as well as store image for the graph towards the end of our code.
# The pickles are read and the data is fed into an RF model.
#
# Finally, we have two graphs showing the RF results vs. the fitted model as well as predicted results vs. actuals and test data

# %%
# %run helper_functions.py
# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Create a folder for every run of the Random forest to store images

# %%
IMAGE_DIR = create_results_perrun()
print("Path of the results Image directory",IMAGE_DIR )
# Out:
# Path of the results Image directory ../Images/RESULTS/RUN-15

# %% [markdown]
# Here we are importing the train and test Data from pickle files created through the EDA file

# %%
city='Los_Angeles'
X_train = pd.read_pickle(f'{PICKLE_PATH}/X_train_{city}.pkl')
Y_train = pd.read_pickle(f'{PICKLE_PATH}/Y_train_{city}.pkl')

X_test  = pd.read_pickle(f'{PICKLE_PATH}/X_test_{city}.pkl')
Y_test  = pd.read_pickle(f'{PICKLE_PATH}/Y_test_{city}.pkl')

print("Shape of Training Dataset " , X_train.shape)
print("Shape of Testing Dataset " , X_test.shape)
# Out:
# Shape of Training Dataset  (1432, 31)
# Shape of Testing Dataset  (90, 31)

# %%
# Fitting a decision tree regressor with max depth and n_estimators
max_depth = 8
n_estimators = 50
fitted_model = RandomForestRegressor(max_depth=max_depth, random_state=0, n_estimators=n_estimators)
fitted_model.fit(X_train, Y_train)

# Dataframe to show features and their importances
top_features = 10
features_importances_df= show_feature_importances(X_train.columns.values.tolist(),
                                                  fitted_model.feature_importances_,top_features)
features_importances_df
# Out:
#                      Features  Feature Importances in (%)
# 6           temperature_mavg2                   98.128928
# 0            temperature_lag1                    1.137553
# 1            temperature_lag2                    0.196494
# 21  enhanced_nao_value_lag365                    0.044277
# 13    enhanced_ao_value_lag30                    0.041907
# 3           temperature_lag30                    0.032616
# 7           temperature_mavg7                    0.030422
# 19    enhanced_nao_value_lag7                    0.027545
# 18    enhanced_nao_value_lag2                    0.026210
# 2            temperature_lag7                    0.026082

# %%
# Run the model on the training dataset
Y_train_pred = fitted_model.predict(X_train)
# Calculate mean squared error for the predicted values
mse_train = mean_squared_error(Y_train, Y_train_pred)
print('Mean Squared Error for the training dataset: %.3f' % mse_train)
# Out:
# Mean Squared Error for the training dataset: 0.060

# %%
# Run the model on the testing dataset
Y_test_pred = fitted_model.predict(X_test)
# Calculate mean squared error for the test vs predicted values
mse_test = mean_squared_error(Y_test, Y_test_pred)
print('Mean Squared Error for the testing dataset: %.3f' % mse_test)
# Out:
# Mean Squared Error for the testing dataset: 0.366

# %%
# Creating a dataframe for predicted/fitted values
future_forecast = pd.DataFrame(Y_test_pred,index = Y_test.index,columns=['Fitted'])

# Concatenate the predicted/fitted values with actual values to display graphs
predictions = pd.concat([Y_test,future_forecast],axis=1)
predictions.columns = ["Actual","Fitted"]

# Displaying few of the predicted values
predictions.head(10)
# Out:
#                Actual     Fitted
# datetime
# 2017-09-02  30.183750  29.218853
# 2017-09-03  30.973333  29.532528
# 2017-09-04  25.004167  27.531416
# 2017-09-05  23.995833  23.977647
# 2017-09-06  24.896250  24.269558
# 2017-09-07  23.748333  24.276287
# 2017-09-08  23.372500  23.226363
# 2017-09-09  22.320417  22.229922
# 2017-09-10  23.954583  23.437974
# 2017-09-11  25.469583  25.203804

# %%
city = city.replace('_',' ')
# Plotting the daily predicted temperature vs Actual Temperature - Decision Tree
fig = charter_helper_fitted("Daily Predicted Temperature using Decision Tree for "+ city, predictions)
iplot(fig)
#py.image.save_as(fig, f'{IMAGE_DIR}/Daily_DT_actual_vs_predict.png')
# Out:
# <div id="001f73b9-04fc-4f1f-9f03-6fb56c9ac25c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plotly.att.com";
#         Plotly.plot(
#             '001f73b9-04fc-4f1f-9f03-6fb56c9ac25c',
#             [{"name": "Actual", "x": ["2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-09-30", "2017-10-01", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-07", "2017-10-08", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-14", "2017-10-15", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-21", "2017-10-22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28", "2017-10-29", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-04", "2017-11-05", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-11", "2017-11-12", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-18", "2017-11-19", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-23", "2017-11-24", "2017-11-25", "2017-11-26", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30"], "y": [30.18375000000003, 30.97333333333336, 25.004166666666688, 23.995833333333355, 24.896250000000023, 23.748333333333353, 23.37250000000002, 22.320416666666688, 23.95458333333336, 25.469583333333357, 24.396250000000027, 21.991666666666685, 20.242500000000025, 20.469166666666684, 20.589166666666685, 20.495000000000022, 19.972083333333362, 20.90166666666669, 20.587916666666686, 20.36302033408335, 17.865416666666686, 17.929166666666685, 19.550833333333355, 22.068333333333346, 22.126250000000024, 21.56625000000002, 22.336215200458355, 23.20291666666669, 21.940416666666696, 20.47708333333335, 19.92958333333335, 19.558333333333355, 18.662916666666693, 19.957083333333355, 21.63833333333335, 23.93250000000002, 21.78458333333336, 20.796666666666688, 21.422083333333358, 19.823333333333352, 18.962500000000023, 18.592083333333353, 19.774250000000023, 23.15625000000001, 24.42666666666669, 24.522083333333356, 24.052916666666686, 21.145833333333353, 19.305000000000014, 18.504583333333354, 21.48000000000002, 25.885000000000023, 30.895833333333346, 30.146666666666686, 25.286250000000024, 22.307500000000022, 20.40916666666669, 18.636666666666688, 18.419166666666683, 18.123333333333353, 18.235000000000024, 17.611666666666686, 17.22666666666668, 17.179166666666685, 17.67875000000002, 17.07666666666668, 18.013333333333353, 18.15762108558335, 18.109012328500018, 16.946250000000017, 15.689988296208353, 15.853750000000018, 15.731666666666689, 16.654166666666686, 17.97034089854169, 19.003333333333355, 19.582083333333355, 17.352500000000017, 17.299583333333356, 15.820416666666686, 18.979583333333355, 22.37833333333336, 23.58916666666669, 21.030416666666685, 19.876666666666683, 17.274166666666687, 16.214583333333355, 14.36279166666669, 16.07708333333336, 21.78000000000003], "type": "scatter", "uid": "7653cf08-9dc2-11e8-b5ee-3c15c2df16f6"}, {"name": "Fitted", "x": ["2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-09-30", "2017-10-01", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-07", "2017-10-08", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-14", "2017-10-15", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-21", "2017-10-22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28", "2017-10-29", "2017-10-30", "20 ...
#             {"title": "Daily Predicted Temperature using Decision Tree for Los Angeles", "xaxis": {"rangeselector": {"buttons": [{"step": "all"}, {"count": 1, "label": "1m", "step": "month", "stepmode": "backward"}]}, "rangeslider": {"visible": true}, "type": "date"}},
#             {"showLink": true, "linkText": "Export to plotly.att.com"}
#         ).then(function () {return Plotly.addFrames('001f73b9-04fc-4f1f-9f03-6fb56c9ac25c',{});}).then(function(){Plotly.animate('001f73b9-04fc-4f1f-9f03-6fb56c9ac25c');})
#         });</script>

# %%
# Plotting the training data for past year, Actual/test data and predicted temperature - Decision Tree
fig = charter_helper_prediction("Daily Predicted Temperature using Decision Tree for " + city, 
                     X_train,Y_train,X_test,Y_test,future_forecast)

iplot(fig)
#py.image.save_as(fig, f'{IMAGE_DIR}/Daily_DT_predict.png')
# Out:
# <div id="51e0349f-ff10-4fe9-afb9-f42c9e06bf77" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plotly.att.com";
#         Plotly.plot(
#             '51e0349f-ff10-4fe9-afb9-f42c9e06bf77',
#             [{"name": "Train temperature", "x": ["2016-09-02", "2016-09-03", "2016-09-04", "2016-09-05", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-10", "2016-09-11", "2016-09-12", "2016-09-13", "2016-09-14", "2016-09-15", "2016-09-16", "2016-09-17", "2016-09-18", "2016-09-19", "2016-09-20", "2016-09-21", "2016-09-22", "2016-09-23", "2016-09-24", "2016-09-25", "2016-09-26", "2016-09-27", "2016-09-28", "2016-09-29", "2016-09-30", "2016-10-01", "2016-10-02", "2016-10-03", "2016-10-04", "2016-10-05", "2016-10-06", "2016-10-07", "2016-10-08", "2016-10-09", "2016-10-10", "2016-10-11", "2016-10-12", "2016-10-13", "2016-10-14", "2016-10-15", "2016-10-16", "2016-10-17", "2016-10-18", "2016-10-19", "2016-10-20", "2016-10-21", "2016-10-22", "2016-10-23", "2016-10-24", "2016-10-25", "2016-10-26", "2016-10-27", "2016-10-28", "2016-10-29", "2016-10-30", "2016-10-31", "2016-11-01", "2016-11-02", "2016-11-03", "2016-11-04", "2016-11-05", "2016-11-06", "2016-11-07", "2016-11-08", "2016-11-09", "2016-11-10", "2016-11-11", "2016-11-12", "2016-11-13", "2016-11-14", "2016-11-15", "2016-11-16", "2016-11-17", "2016-11-18", "2016-11-19", "2016-11-20", "2016-11-21", "2016-11-22", "2016-11-23", "2016-11-24", "2016-11-25", "2016-11-26", "2016-11-27", "2016-11-28", "2016-11-29", "2016-11-30", "2016-12-01", "2016-12-02", "2016-12-03", "2016-12-04", "2016-12-05", "2016-12-06", "2016-12-07", "2016-12-08", "2016-12-09", "2016-12-10", "2016-12-11", "2016-12-12", "2016-12-13", "2016-12-14", "2016-12-15", "2016-12-16", "2016-12-17", "2016-12-18", "2016-12-19", "2016-12-20", "2016-12-21", "2016-12-22", "2016-12-23", "2016-12-24", "2016-12-25", "2016-12-26", "2016-12-27", "2016-12-28", "2016-12-29", "2016-12-30", "2016-12-31", "2017-01-01", "2017-01-02", "2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-07", "2017-01-08", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-14", "2017-01-15", "2017-01-16", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-21", "2017-01-22", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-28", "2017-01-29", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-04", "2017-02-05", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-11", "2017-02-12", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-18", "2017-02-19", "2017-02-20", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-25", "2017-02-26", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-04", "2017-03-05", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-11", "2017-03-12", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-18", "2017-03-19", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-25", "2017-03-26", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-01", "2017-04-02", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-08", "2017-04-09", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-14", "2017-04-15", "2017-04-16", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-22", "2017-04-23", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-04-29", "2017-04-30", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-06", "2017-05-07", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-13", "2017-05-14", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-20", "2017-05-21", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-27", "2017-05-28", "2017-05-29", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-03", "2017-06-04", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-10", "20 ...

# %%
results = update_results_function('RANDOM FOREST',f'{city}',X_train._metadata["feature_set_type"],
                                  {'max_depth': max_depth , 'n_estimators':n_estimators, 'Info': X_train._metadata}, 
                                  {'features' : X_train.columns.values.tolist(),
                                   'importances':fitted_model.feature_importances_,
                                   'mse_train' : mse_train}, 
                                    mse_test) 
results
# Out:
#     RUN NO                   DATETIME     MODEL NAME         CITY  \
# 0    RUN-1 2018-08-11 02:35:23.882031  DECISION TREE     New York
# 1    RUN-2 2018-08-11 02:42:21.539158  DECISION TREE     New York
# 2    RUN-3 2018-08-11 02:55:40.130331  DECISION TREE     New York
# 3    RUN-4 2018-08-11 02:58:39.851712  DECISION TREE     New York
# 4    RUN-5 2018-08-11 02:59:40.073802  RANDOM FOREST     New York
# 5    RUN-6 2018-08-11 03:42:53.491706            RNN     New York
# 6    RUN-7 2018-08-11 03:55:27.381404          ARIMA     New York
# 7    RUN-8 2018-08-11 04:08:13.465006  DECISION TREE     New York
# 8    RUN-9 2018-08-11 04:08:20.505215  RANDOM FOREST     New York
# 9   RUN-10 2018-08-11 04:08:48.142332            RNN     New York
# 10  RUN-11 2018-08-11 04:08:48.987756          ARIMA     New York
# 11  RUN-12 2018-08-11 16:56:26.016375  DECISION TREE     New York
# 12  RUN-13 2018-08-11 16:56:54.466059  DECISION TREE  Los Angeles
# 13  RUN-14 2018-08-11 16:57:25.395937  RANDOM FOREST  Los Angeles
# 14  RUN-15 2018-08-11 16:58:39.009713  RANDOM FOREST  Los Angeles
#
#          FEATURE_TYPE HOST_MACHINE  \
# 0                      ELS-F25750M
# 1   Enhanced Features  ELS-F25750M
# 2   Enhanced Features  ELS-F25750M
# 3   Enhanced Features  ELS-F25750M
# 4   Enhanced Features  ELS-F25750M
# 5   Enhanced Features  ELS-F25750M
# 6   Enhanced Features  ELS-F25750M
# 7   Enhanced Features  ELS-F25750M
# 8   Enhanced Features  ELS-F25750M
# 9   Enhanced Features  ELS-F25750M
# 10  Enhanced Features  ELS-F25750M
# 11  Enhanced Features  ELS-F25750M
# 12  Enhanced Features  ELS-F25750M
# 13  Enhanced Features  ELS-F25750M
# 14  Enhanced Features  ELS-F25750M
#
#                                            PARAMETERS  \
# 0   {'max_depth': 8, 'Info': {'city': 'New York', ...
# 1   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 2   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 3   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 4   {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 5   {'epochs': 50, 'Info': {'feature_set_type': 'E...
# 6                                {'order': (7, 0, 1)}
# 7   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 8   {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 9   {'epochs': 50, 'Info': {'feature_set_type': 'E...
# 10                               {'order': (7, 0, 1)}
# 11  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 12  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 13  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 14  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
#
#                                               RESULTS  MEAN SQUARED ERROR
# 0   {'features': ['temperature_lag1', 'temperature...            0.519263
# 1   {'features': ['temperature_lag1', 'temperature...            0.507592
# 2   {'features': ['temperature_lag1', 'temperature...            0.512219
# 3   {'features': ['temperature_lag1', 'temperature...            0.544546
# 4   {'features': ['temperature_lag1', 'temperature...            0.321614
# 5   {'features': ['temperature_lag1', 'temperature...           19.882019
# 6                       {'features': ['temperature']}           27.117410
# 7   {'features': ['temperature_lag1', 'temperature...            0.511456
# 8   {'features': ['temperature_lag1', 'temperature...            0.321614
# 9   {'features': ['temperature_lag1', 'temperature...           11.206590
# 10                      {'features': ['temperature']}           27.117410
# 11  {'features': ['temperature_lag1', 'temperature...            0.441595
# 12  {'features': ['temperature_lag1', 'temperature...            0.632571
# 13  {'features': ['temperature_lag1', 'temperature...            0.365879
# 14  {'features': ['temperature_lag1', 'temperature...            0.365879
