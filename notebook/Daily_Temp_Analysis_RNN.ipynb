# %% [markdown]
# # Time Series to observe DAILY temperature variations
# ## Daily temperature prediction using RNN

# %% [markdown]
# Moving from predictive Machine Learning classifier to Unpredicitve Neural Nets, we use Sequential ** Recurrent Neural Net (RNN)** in the notebook below.
#
# You need to ensure that you have the right environment installed on top of your python3 to run Keras and Tensorflow. Two libraries needed to successfully run (RNN).
#
# Just like in the other models, we begin by loading all necessary libraries and paths to read the "pickles" as well as store image for the graph towards the end of our code. The pickles are read and the data is fed into an RNN model.
# Finally, we have two graphs showing the DT results vs. the fitted model as well as predicted results vs. actuals and test data

# %% [markdown]
# Here we are importing the train and test Data from pickle files created through the EDA file

# %%
import warnings
warnings.filterwarnings('ignore')

# %run helper_functions.py
# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Create a folder for every run of the RNN to store images

# %%
city='Miami' # New_York Atlanta Boston Dallas Houston Miami
analysis_type = 'Enhanced_Signals' # Basic, Inc_Signals, Enhanced_Signals

# %%
EXPERIMENT_DIR, EXPERIMENT_ID  = create_results_perrun()
print("Path of the results directory",EXPERIMENT_DIR )
# Out:
# Path of the results directory ../experiment_results/RUN-54

# %%
#EXPERIMENT_DIR = '../experiment_results/RUN-37'
#EXPERIMENT_ID = 37

# %%
X_train = pd.read_pickle(f'{PICKLE_PATH}/X_train_{city}_{analysis_type}.pkl')
Y_train = pd.read_pickle(f'{PICKLE_PATH}/Y_train_{city}_{analysis_type}.pkl')

X_test  = pd.read_pickle(f'{PICKLE_PATH}/X_test_{city}_{analysis_type}.pkl')
Y_test  = pd.read_pickle(f'{PICKLE_PATH}/Y_test_{city}_{analysis_type}.pkl')

print("Shape of Training Dataset " , X_train.shape)
print("Shape of Testing Dataset " , X_test.shape)
# Out:
# Shape of Training Dataset  (1399, 17)
# Shape of Testing Dataset  (90, 17)

# %%
# Function to fit a sequential rnn with loss estimate being mean squared error
def train_model(X_train, y_train, X_test, y_test, epochs):
    model = Sequential(
        [
            Dense(10, activation="relu", input_shape=(X_train.shape[1],)),
            Dense(10, activation="relu"),
            Dense(10, activation="relu"),
            Dense(1, activation="linear")
        ]
    )
    model.compile(optimizer=Adam(lr=0.001), loss="mean_squared_error")
    
    history = model.fit(X_train, y_train, epochs=epochs, shuffle=False)
    return model, history

# %%
# Function to fit a sequential rnn with epochs = 50
epochs = 50
model_encoded, encoded_hist = train_model(
    X_train,
    Y_train,
    X_test,
    Y_test,
    epochs=epochs
)
# Out:
# Epoch 1/50
# 1399/1399 [==============================] - 1s 956us/step - loss: 780.4398
# Epoch 2/50
# 1399/1399 [==============================] - 0s 74us/step - loss: 565.0433
# Epoch 3/50
# 1399/1399 [==============================] - 0s 72us/step - loss: 346.5662
# Epoch 4/50
# 1399/1399 [==============================] - 0s 84us/step - loss: 45.1367
# Epoch 5/50
# 1399/1399 [==============================] - 0s 85us/step - loss: 7.4433
# Epoch 6/50
# 1399/1399 [==============================] - 0s 78us/step - loss: 6.7492
# Epoch 7/50
# 1399/1399 [==============================] - 0s 74us/step - loss: 6.6773
# Epoch 8/50
# 1399/1399 [==============================] - 0s 65us/step - loss: 6.6082
# Epoch 9/50
# 1399/1399 [==============================] - 0s 69us/step - loss: 6.5385
# Epoch 10/50
# 1399/1399 [==============================] - 0s 70us/step - loss: 6.4698
# Epoch 11/50
# 1399/1399 [==============================] - 0s 68us/step - loss: 6.4028
# Epoch 12/50
# 1399/1399 [==============================] - 0s 70us/step - loss: 6.3369
# Epoch 13/50
# 1399/1399 [==============================] - 0s 66us/step - loss: 6.2723
# Epoch 14/50
# 1399/1399 [==============================] - 0s 72us/step - loss: 6.2086
# Epoch 15/50
# 1399/1399 [==============================] - 0s 74us/step - loss: 6.1460
# Epoch 16/50
# 1399/1399 [==============================] - 0s 71us/step - loss: 6.0850
# Epoch 17/50
# 1399/1399 [==============================] - 0s 71us/step - loss: 6.0246
# Epoch 18/50
# 1399/1399 [==============================] - 0s 66us/step - loss: 5.9650
# Epoch 19/50
# 1399/1399 [==============================] - 0s 66us/step - loss: 5.9058
# Epoch 20/50
# 1399/1399 [==============================] - 0s 64us/step - loss: 5.8478
# Epoch 21/50
# 1399/1399 [==============================] - 0s 99us/step - loss: 5.7902
# Epoch 22/50
# 1399/1399 [==============================] - 0s 119us/step - loss: 5.7333
# Epoch 23/50
# 1399/1399 [==============================] - 0s 115us/step - loss: 5.6767
# Epoch 24/50
# 1399/1399 [==============================] - 0s 86us/step - loss: 5.6200
# Epoch 25/50
# 1399/1399 [==============================] - 0s 90us/step - loss: 5.5636
# Epoch 26/50
# 1399/1399 [==============================] - 0s 93us/step - loss: 5.5073
# Epoch 27/50
# 1399/1399 [==============================] - 0s 79us/step - loss: 5.4509
# Epoch 28/50
# 1399/1399 [==============================] - 0s 74us/step - loss: 5.3945
# Epoch 29/50
# 1399/1399 [==============================] - 0s 66us/step - loss: 5.3377
# Epoch 30/50
# 1399/1399 [==============================] - 0s 69us/step - loss: 5.2806
# Epoch 31/50
# 1399/1399 [==============================] - 0s 70us/step - loss: 5.2232
# Epoch 32/50
# 1399/1399 [==============================] - 0s 74us/step - loss: 5.1663
# Epoch 33/50
# 1399/1399 [==============================] - 0s 66us/step - loss: 5.1076
# Epoch 34/50
# 1399/1399 [==============================] - 0s 65us/step - loss: 5.0478
# Epoch 35/50
# 1399/1399 [==============================] - 0s 73us/step - loss: 4.9864
# Epoch 36/50
# 1399/1399 [==============================] - 0s 74us/step - loss: 4.9238
# Epoch 37/50
# 1399/1399 [==============================] - 0s 74us/step - loss: 4.8596
# Epoch 38/50
# 1399/1399 [==============================] - 0s 81us/step - loss: 4.7944
# Epoch 39/50
# 1399/1399 [==============================] - 0s 80us/step - loss: 4.7275
# Epoch 40/50
# 1399/1399 [==============================] - 0s 67us/step - loss: 4.6592
# Epoch 41/50
# 1399/1399 [==============================] - 0s 64us/step - loss: 4.5889
# Epoch 42/50
# 1399/1399 [==============================] - 0s 64us/step - loss: 4.5169
# Epoch 43/50
# 1399/1399 [==============================] - 0s 70us/step - loss: 4.4425
# Epoch 44/50
# 1399/1399 [==============================] - 0s 67us/step - loss: 4.3672
# Epoch 45/50
# 1399/1399 [==============================] - 0s 72us/step - loss: 4.2900
# Epoch 46/50
# 1399/1399 [==============================] - 0s 76us/step - loss: 4.2125
# Epoch 47/50
# 1399/1399 [==============================] - 0s 81us/step - loss: 4.1347
# Epoch 48/50
# 1399/1399 [==============================] - 0s 74us/step - loss: 4.0546
# Epoch 49/50
# 1399/1399 [==============================] - 0s 81us/step - loss: 3.9830
# Epoch 50/50
# 1399/1399 [==============================] - 0s 67us/step - loss: 3.9069

# %%
# Run the model on the training dataset
Y_train_pred = model_encoded.predict(X_train)
# Calculate mean squared error for the predicted values
mse_train = mean_squared_error(Y_train, model_encoded.predict(X_train))
print('Mean Squared Error for the training dataset: %.3f' % mse_train)
# Out:
# Mean Squared Error for the training dataset: 3.901

# %%
# Run the model on the testing dataset
Y_test_pred = model_encoded.predict(X_test)
# Calculate mean squared error for the test vs predicted values
mse_test = mean_squared_error(Y_test, model_encoded.predict(X_test))
print('Mean Squared Error for the testing dataset: %.3f' % mse_test)
# Out:
# Mean Squared Error for the testing dataset: 2.013

# %%
# Creating a dataframe for predicted/fitted values
future_forecast = pd.DataFrame(Y_test_pred,index = Y_test.index,columns=['Fitted'])

# Concatenate the predicted/fitted values with actual values to display graphs
predictions = pd.concat([Y_test,future_forecast],axis=1)
predictions.columns = ["Actual","Fitted"]

# Displaying few of the predicted values
predictions.head(10)
# Out:
#                Actual     Fitted
# datetime
# 2017-07-31  26.192917  29.396700
# 2017-08-01  26.835000  28.911028
# 2017-08-02  27.449583  28.666040
# 2017-08-03  30.198333  28.672266
# 2017-08-04  30.380000  29.811632
# 2017-08-05  30.513333  29.973490
# 2017-08-06  30.326667  29.948656
# 2017-08-07  30.024583  29.224321
# 2017-08-08  30.094583  28.931959
# 2017-08-09  30.160833  29.316683

# %%
city = city.replace('_',' ')
# Plotting the daily predicted temperature vs Actual Temperature - RNN
fig = charter_helper_fitted(f"Daily Predicted Temperature using RNN for {city} using {analysis_type}", predictions)
iplot(fig)

py.image.save_as(fig, f'{EXPERIMENT_DIR}/Daily_actual_vs_predict.png')
# Out:
# <div id="0df79b1c-bd54-4242-90fe-e84f59c4c325" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '0df79b1c-bd54-4242-90fe-e84f59c4c325',
#             [{"name": "Actual", "x": ["2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-05", "2017-08-06", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-12", "2017-08-13", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-19", "2017-08-20", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-26", "2017-08-27", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-09-30", "2017-10-01", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-07", "2017-10-08", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-14", "2017-10-15", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-21", "2017-10-22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28"], "y": [26.19291666666668, 26.83500000000002, 27.44958333333335, 30.19833333333334, 30.380000000000013, 30.51333333333335, 30.32666666666668, 30.02458333333335, 30.094583333333343, 30.160833333333347, 27.81333333333335, 27.655000000000015, 28.471250000000012, 29.42875000000002, 29.586666666666677, 29.54458333333335, 29.749000000000013, 30.39250000000001, 30.527083333333355, 30.049583333333345, 28.470833333333342, 30.121666666666687, 29.48583333333335, 28.019166666666678, 26.576250000000005, 25.360416666666676, 25.80583333333335, 26.52000000000001, 27.790416666666687, 28.69916666666667, 29.887500000000017, 30.37958333333334, 30.309583333333336, 28.374166666666696, 29.24666666666668, 29.15291666666667, 29.559583333333347, 29.012500000000006, 29.349583333333342, 30.48708333333335, 29.152916666666698, 26.39083333333335, 28.747375000000005, 30.872500000000027, 28.70958333333336, 28.80875000000003, 28.988750000000028, 29.062500000000014, 28.693333333333346, 28.023333333333344, 28.635416666666686, 28.491666666666685, 27.91808072916668, 27.40875000000001, 27.65583333333335, 28.082083333333355, 28.493750000000016, 27.663750000000018, 27.678333333333345, 28.03433459350001, 26.446666666666683, 26.923750000000023, 28.324166666666684, 27.865416666666686, 27.826250000000016, 26.81458333333335, 26.141666666666694, 28.37500000000001, 29.016250000000014, 28.959583333333345, 28.636666666666674, 28.768333333333345, 28.028750000000013, 26.99125000000002, 27.268333333333345, 27.901750000000018, 27.71583333333335, 27.498333333333346, 27.14375000000001, 26.863750000000024, 26.285000000000014, 27.46000000000002, 27.386666666666674, 28.108750000000025, 28.024166666666677, 26.862916666666674, 22.960416666666685, 18.995416666666685, 22.152500000000014, 24.49000000000001], "type": "scatter", "uid": "7abea6ee-a01b-11e8-85fe-00215cc353c9"}, {"name": "Fitted", "x": ["2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-05", "2017-08-06", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-12", "2017-08-13", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-19", "2017-08-20", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-26", "2017-08-27", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09- ...
#             {"title": "Daily Predicted Temperature using RNN for Miami using Enhanced_Signals", "xaxis": {"rangeselector": {"buttons": [{"step": "all"}, {"count": 1, "label": "1m", "step": "month", "stepmode": "backward"}]}, "rangeslider": {"visible": true}, "type": "date"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('0df79b1c-bd54-4242-90fe-e84f59c4c325',{});}).then(function(){Plotly.animate('0df79b1c-bd54-4242-90fe-e84f59c4c325');})
#         });</script>

# %%
 # Plotting the training data for past year, Actual/test data and predicted temperature - Decision Tree
fig = charter_helper_prediction(f"Daily Predicted Temperature using RNN for {city} using {analysis_type}", 
                     X_train,Y_train,X_test,Y_test,future_forecast)

iplot(fig)

py.image.save_as(fig, f'{EXPERIMENT_DIR}/Daily_predict.png')
# Out:
# <div id="eddbc80d-fa71-44c3-8be6-fcc3d5186862" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'eddbc80d-fa71-44c3-8be6-fcc3d5186862',
#             [{"name": "Train temperature", "x": ["2016-07-31", "2016-08-01", "2016-08-02", "2016-08-03", "2016-08-04", "2016-08-05", "2016-08-06", "2016-08-07", "2016-08-08", "2016-08-09", "2016-08-10", "2016-08-11", "2016-08-12", "2016-08-13", "2016-08-14", "2016-08-15", "2016-08-16", "2016-08-17", "2016-08-18", "2016-08-19", "2016-08-20", "2016-08-21", "2016-08-22", "2016-08-23", "2016-08-24", "2016-08-25", "2016-08-26", "2016-08-27", "2016-08-28", "2016-08-29", "2016-08-30", "2016-08-31", "2016-09-01", "2016-09-02", "2016-09-03", "2016-09-04", "2016-09-05", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-10", "2016-09-11", "2016-09-12", "2016-09-13", "2016-09-14", "2016-09-15", "2016-09-16", "2016-09-17", "2016-09-18", "2016-09-19", "2016-09-20", "2016-09-21", "2016-09-22", "2016-09-23", "2016-09-24", "2016-09-25", "2016-09-26", "2016-09-27", "2016-09-28", "2016-09-29", "2016-09-30", "2016-10-01", "2016-10-02", "2016-10-03", "2016-10-04", "2016-10-05", "2016-10-06", "2016-10-07", "2016-10-08", "2016-10-09", "2016-10-10", "2016-10-11", "2016-10-12", "2016-10-13", "2016-10-14", "2016-10-15", "2016-10-16", "2016-10-17", "2016-10-18", "2016-10-19", "2016-10-20", "2016-10-21", "2016-10-22", "2016-10-23", "2016-10-24", "2016-10-25", "2016-10-26", "2016-10-27", "2016-10-28", "2016-10-29", "2016-10-30", "2016-10-31", "2016-11-01", "2016-11-02", "2016-11-03", "2016-11-04", "2016-11-05", "2016-11-06", "2016-11-07", "2016-11-08", "2016-11-09", "2016-11-10", "2016-11-11", "2016-11-12", "2016-11-13", "2016-11-14", "2016-11-15", "2016-11-16", "2016-11-17", "2016-11-18", "2016-11-19", "2016-11-20", "2016-11-21", "2016-11-22", "2016-11-23", "2016-11-24", "2016-11-25", "2016-11-26", "2016-11-27", "2016-11-28", "2016-11-29", "2016-11-30", "2016-12-01", "2016-12-02", "2016-12-03", "2016-12-04", "2016-12-05", "2016-12-06", "2016-12-07", "2016-12-08", "2016-12-09", "2016-12-10", "2016-12-11", "2016-12-12", "2016-12-13", "2016-12-14", "2016-12-15", "2016-12-16", "2016-12-17", "2016-12-18", "2016-12-19", "2016-12-20", "2016-12-21", "2016-12-22", "2016-12-23", "2016-12-24", "2016-12-25", "2016-12-26", "2016-12-27", "2016-12-28", "2016-12-29", "2016-12-30", "2016-12-31", "2017-01-01", "2017-01-02", "2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-07", "2017-01-08", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-14", "2017-01-15", "2017-01-16", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-21", "2017-01-22", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-28", "2017-01-29", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-04", "2017-02-05", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-11", "2017-02-12", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-18", "2017-02-19", "2017-02-20", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-25", "2017-02-26", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-04", "2017-03-05", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-11", "2017-03-12", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-18", "2017-03-19", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-25", "2017-03-26", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-01", "2017-04-02", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-08", "2017-04-09", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-14", "2017-04-15", "2017-04-16", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-22", "2017-04-23", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-04-29", "2017-04-30", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-06", "2017-05-07", "2017-05-08", "20 ...

# %%
results = update_results_function(EXPERIMENT_ID, 'RNN',city,analysis_type,
                                  {'epochs': epochs,'Info': X_train._metadata}, 
                                  {'features' : X_train.columns.values.tolist(),
                                   'importances':'NA',
                                   'mse_train' : mse_train}, 
                                    mse_test)

# %%
results.tail(1)
# Out:
#    RUN_ID                   DATETIME MODEL_NAME   CITY      FEATURE_TYPE  \
# 53     54 2018-08-14 20:40:54.336628        RNN  Miami  Enhanced_Signals
#
#        HOST_MACHINE                                   MODEL_PARAMETERS  \
# 53  DESKTOP-KN40C32  {'epochs': 50, 'Info': {'feature_set_type': 'E...
#
#                                         MODEL_RESULTS  MEAN_SQUARED_ERROR
# 53  {'features': ['temperature_lag1', 'temperature...             2.01286

# %%
results = pd.read_pickle('../pickles/results.pkl')
results
# Out:
#    RUN_ID                   DATETIME     MODEL_NAME      CITY  \
# 0       1 2018-08-14 19:41:45.275297  DECISION TREE  New York
# 1       2 2018-08-14 19:42:13.654060  DECISION TREE   Atlanta
# 2       3 2018-08-14 19:42:23.328525  DECISION TREE    Boston
# 3       4 2018-08-14 19:42:30.715058  DECISION TREE    Dallas
# 4       5 2018-08-14 19:42:41.506483  DECISION TREE   Houston
# 5       6 2018-08-14 19:42:49.124681  DECISION TREE     Miami
# 6       7 2018-08-14 19:43:04.972617  DECISION TREE  New York
# 7       8 2018-08-14 19:43:12.930159  DECISION TREE   Atlanta
# 8       9 2018-08-14 19:43:20.383683  DECISION TREE    Boston
# 9      10 2018-08-14 19:43:32.825549  DECISION TREE    Dallas
# 10     11 2018-08-14 19:43:39.374706  DECISION TREE   Houston
# 11     12 2018-08-14 19:43:48.176029  DECISION TREE     Miami
# 12     13 2018-08-14 19:44:00.243495  DECISION TREE  New York
# 13     14 2018-08-14 19:44:07.609795  DECISION TREE   Atlanta
# 14     15 2018-08-14 19:44:14.731752  DECISION TREE    Boston
# 15     16 2018-08-14 19:44:20.754761  DECISION TREE    Dallas
# 16     17 2018-08-14 19:44:46.805353  DECISION TREE     Miami
# 17     18 2018-08-14 19:48:11.736850  DECISION TREE   Houston
# 18     19 2018-08-14 19:53:51.786200  RANDOM FOREST  New York
# 19     20 2018-08-14 19:54:40.149363  RANDOM FOREST   Atlanta
# 20     21 2018-08-14 19:54:48.599391  RANDOM FOREST    Boston
# 21     22 2018-08-14 19:54:57.660172  RANDOM FOREST    Dallas
# 22     23 2018-08-14 19:55:04.570078  RANDOM FOREST   Houston
# 23     24 2018-08-14 19:55:11.164461  RANDOM FOREST     Miami
# 24     25 2018-08-14 19:55:22.399240  RANDOM FOREST  New York
# 25     26 2018-08-14 19:55:31.041998  RANDOM FOREST   Atlanta
# 26     27 2018-08-14 19:55:39.652542  RANDOM FOREST    Boston
# 27     28 2018-08-14 19:55:47.002009  RANDOM FOREST    Dallas
# 28     29 2018-08-14 19:55:55.798404  RANDOM FOREST   Houston
# 29     30 2018-08-14 19:56:00.644376  RANDOM FOREST     Miami
# 30     31 2018-08-14 19:56:16.424827  RANDOM FOREST  New York
# 31     32 2018-08-14 19:56:23.951216  RANDOM FOREST   Atlanta
# 32     33 2018-08-14 19:56:30.584670  RANDOM FOREST    Boston
# 33     34 2018-08-14 19:56:37.269205  RANDOM FOREST    Dallas
# 34     35 2018-08-14 19:56:44.111200  RANDOM FOREST   Houston
# 35     36 2018-08-14 19:56:51.638468  RANDOM FOREST     Miami
# 36     37 2018-08-14 20:33:25.810145            RNN  New York
# 37     38 2018-08-14 20:34:21.973872            RNN   Atlanta
# 38     39 2018-08-14 20:34:39.550435            RNN    Boston
# 39     40 2018-08-14 20:34:55.307517            RNN    Dallas
# 40     41 2018-08-14 20:35:12.061515            RNN   Houston
# 41     42 2018-08-14 20:35:28.587513            RNN     Miami
# 42     43 2018-08-14 20:35:48.643558            RNN  New York
# 43     44 2018-08-14 20:36:38.538124            RNN   Atlanta
# 44     45 2018-08-14 20:37:08.003250            RNN    Boston
# 45     46 2018-08-14 20:37:30.002193            RNN    Dallas
# 46     47 2018-08-14 20:37:47.827488            RNN   Houston
# 47     48 2018-08-14 20:38:20.610680            RNN     Miami
# 48     49 2018-08-14 20:38:45.591679            RNN  New York
# 49     50 2018-08-14 20:39:13.461675            RNN   Atlanta
# 50     51 2018-08-14 20:39:52.178626            RNN    Boston
# 51     52 2018-08-14 20:40:06.720627            RNN    Dallas
# 52     53 2018-08-14 20:40:23.868627            RNN   Houston
# 53     54 2018-08-14 20:40:54.336628            RNN     Miami
#
#         FEATURE_TYPE     HOST_MACHINE  \
# 0              Basic  DESKTOP-KN40C32
# 1              Basic  DESKTOP-KN40C32
# 2              Basic  DESKTOP-KN40C32
# 3              Basic  DESKTOP-KN40C32
# 4              Basic  DESKTOP-KN40C32
# 5              Basic  DESKTOP-KN40C32
# 6        Inc_Signals  DESKTOP-KN40C32
# 7        Inc_Signals  DESKTOP-KN40C32
# 8        Inc_Signals  DESKTOP-KN40C32
# 9        Inc_Signals  DESKTOP-KN40C32
# 10       Inc_Signals  DESKTOP-KN40C32
# 11       Inc_Signals  DESKTOP-KN40C32
# 12  Enhanced_Signals  DESKTOP-KN40C32
# 13  Enhanced_Signals  DESKTOP-KN40C32
# 14  Enhanced_Signals  DESKTOP-KN40C32
# 15  Enhanced_Signals  DESKTOP-KN40C32
# 16  Enhanced_Signals  DESKTOP-KN40C32
# 17  Enhanced_Signals  DESKTOP-KN40C32
# 18             Basic  DESKTOP-KN40C32
# 19             Basic  DESKTOP-KN40C32
# 20             Basic  DESKTOP-KN40C32
# 21             Basic  DESKTOP-KN40C32
# 22             Basic  DESKTOP-KN40C32
# 23             Basic  DESKTOP-KN40C32
# 24       Inc_Signals  DESKTOP-KN40C32
# 25       Inc_Signals  DESKTOP-KN40C32
# 26       Inc_Signals  DESKTOP-KN40C32
# 27       Inc_Signals  DESKTOP-KN40C32
# 28       Inc_Signals  DESKTOP-KN40C32
# 29       Inc_Signals  DESKTOP-KN40C32
# 30  Enhanced_Signals  DESKTOP-KN40C32
# 31  Enhanced_Signals  DESKTOP-KN40C32
# 32  Enhanced_Signals  DESKTOP-KN40C32
# 33  Enhanced_Signals  DESKTOP-KN40C32
# 34  Enhanced_Signals  DESKTOP-KN40C32
# 35  Enhanced_Signals  DESKTOP-KN40C32
# 36             Basic  DESKTOP-KN40C32
# 37             Basic  DESKTOP-KN40C32
# 38             Basic  DESKTOP-KN40C32
# 39             Basic  DESKTOP-KN40C32
# 40             Basic  DESKTOP-KN40C32
# 41             Basic  DESKTOP-KN40C32
# 42       Inc_Signals  DESKTOP-KN40C32
# 43       Inc_Signals  DESKTOP-KN40C32
# 44       Inc_Signals  DESKTOP-KN40C32
# 45       Inc_Signals  DESKTOP-KN40C32
# 46       Inc_Signals  DESKTOP-KN40C32
# 47       Inc_Signals  DESKTOP-KN40C32
# 48  Enhanced_Signals  DESKTOP-KN40C32
# 49  Enhanced_Signals  DESKTOP-KN40C32
# 50  Enhanced_Signals  DESKTOP-KN40C32
# 51  Enhanced_Signals  DESKTOP-KN40C32
# 52  Enhanced_Signals  DESKTOP-KN40C32
# 53  Enhanced_Signals  DESKTOP-KN40C32
#
#                                      MODEL_PARAMETERS  \
# 0   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 1   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 2   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 3   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 4   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 5   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 6   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 7   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 8   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 9   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 10  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 11  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 12  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 13  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 14  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 15  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 16  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 17  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 18  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 19  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 20  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 21  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 22  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 23  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 24  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 25  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 26  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 27  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 28  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 29  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 30  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 31  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 32  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 33  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 34  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 35  {'max_depth': 8, 'n_estimators': 50, 'Info': {...
# 36  {'epochs': 50, 'Info': {'feature_set_type': 'B...
# 37  {'epochs': 50, 'Info': {'feature_set_type': 'B...
# 38  {'epochs': 50, 'Info': {'feature_set_type': 'B...
# 39  {'epochs': 50, 'Info': {'feature_set_type': 'B...
# 40  {'epochs': 50, 'Info': {'feature_set_type': 'B...
# 41  {'epochs': 50, 'Info': {'feature_set_type': 'B...
# 42  {'epochs': 50, 'Info': {'feature_set_type': 'I...
# 43  {'epochs': 50, 'Info': {'feature_set_type': 'I...
# 44  {'epochs': 50, 'Info': {'feature_set_type': 'I...
# 45  {'epochs': 50, 'Info': {'feature_set_type': 'I...
# 46  {'epochs': 50, 'Info': {'feature_set_type': 'I...
# 47  {'epochs': 50, 'Info': {'feature_set_type': 'I...
# 48  {'epochs': 50, 'Info': {'feature_set_type': 'E...
# 49  {'epochs': 50, 'Info': {'feature_set_type': 'E...
# 50  {'epochs': 50, 'Info': {'feature_set_type': 'E...
# 51  {'epochs': 50, 'Info': {'feature_set_type': 'E...
# 52  {'epochs': 50, 'Info': {'feature_set_type': 'E...
# 53  {'epochs': 50, 'Info': {'feature_set_type': 'E...
#
#                                         MODEL_RESULTS  MEAN_SQUARED_ERROR
# 0   {'features': ['temperature_lag1', 'temperature...            5.799872
# 1   {'features': ['temperature_lag1', 'temperature...            8.436149
# 2   {'features': ['temperature_lag1', 'temperature...           16.504857
# 3   {'features': ['temperature_lag1', 'temperature...           12.523335
# 4   {'features': ['temperature_lag1', 'temperature...            7.705077
# 5   {'features': ['temperature_lag1', 'temperature...            1.833555
# 6   {'features': ['temperature_lag1', 'temperature...            6.518000
# 7   {'features': ['temperature_lag1', 'temperature...            7.992946
# 8   {'features': ['temperature_lag1', 'temperature...           22.967065
# 9   {'features': ['temperature_lag1', 'temperature...           14.223161
# 10  {'features': ['temperature_lag1', 'temperature...           10.519872
# 11  {'features': ['temperature_lag1', 'temperature...            1.577366
# 12  {'features': ['temperature_lag1', 'temperature...            6.767755
# 13  {'features': ['temperature_lag1', 'temperature...            7.783687
# 14  {'features': ['temperature_lag1', 'temperature...           25.109055
# 15  {'features': ['temperature_lag1', 'temperature...           15.432839
# 16  {'features': ['temperature_lag1', 'temperature...            1.556905
# 17  {'features': ['temperature_lag1', 'temperature...           10.205057
# 18  {'features': ['temperature_lag1', 'temperature...            4.369905
# 19  {'features': ['temperature_lag1', 'temperature...            5.516615
# 20  {'features': ['temperature_lag1', 'temperature...           11.877780
# 21  {'features': ['temperature_lag1', 'temperature...            8.983822
# 22  {'features': ['temperature_lag1', 'temperature...            6.637421
# 23  {'features': ['temperature_lag1', 'temperature...            1.206302
# 24  {'features': ['temperature_lag1', 'temperature...            4.216172
# 25  {'features': ['temperature_lag1', 'temperature...            5.434763
# 26  {'features': ['temperature_lag1', 'temperature...           12.735153
# 27  {'features': ['temperature_lag1', 'temperature...            9.260334
# 28  {'features': ['temperature_lag1', 'temperature...            6.041626
# 29  {'features': ['temperature_lag1', 'temperature...            1.168790
# 30  {'features': ['temperature_lag1', 'temperature...            4.216172
# 31  {'features': ['temperature_lag1', 'temperature...            5.434763
# 32  {'features': ['temperature_lag1', 'temperature...           12.735153
# 33  {'features': ['temperature_lag1', 'temperature...            9.260334
# 34  {'features': ['temperature_lag1', 'temperature...            6.041626
# 35  {'features': ['temperature_lag1', 'temperature...            1.168790
# 36  {'features': ['temperature_lag1', 'temperature...            4.839433
# 37  {'features': ['temperature_lag1', 'temperature...            5.105819
# 38  {'features': ['temperature_lag1', 'temperature...           11.869203
# 39  {'features': ['temperature_lag1', 'temperature...            8.563057
# 40  {'features': ['temperature_lag1', 'temperature...            5.581542
# 41  {'features': ['temperature_lag1', 'temperature...            2.016882
# 42  {'features': ['temperature_lag1', 'temperature...            4.700272
# 43  {'features': ['temperature_lag1', 'temperature...            5.628276
# 44  {'features': ['temperature_lag1', 'temperature...           11.682041
# 45  {'features': ['temperature_lag1', 'temperature...            8.336575
# 46  {'features': ['temperature_lag1', 'temperature...            4.588875
# 47  {'features': ['temperature_lag1', 'temperature...            2.093093
# 48  {'features': ['temperature_lag1', 'temperature...            4.095801
# 49  {'features': ['temperature_lag1', 'temperature...            4.966304
# 50  {'features': ['temperature_lag1', 'temperature...           11.645510
# 51  {'features': ['temperature_lag1', 'temperature...            8.632428
# 52  {'features': ['temperature_lag1', 'temperature...            4.217506
# 53  {'features': ['temperature_lag1', 'temperature...            2.012860
