# %% [markdown]
# # Time Series to observe DAILY temperature variations
# ## Daily temperature prediction using Decision Tree

# %% [markdown]
# Following ARIMA, we use in the notebook below our first classifier:
#
# **Decision Tree (DT)** : Similarly to ARIMA, We begin by loading all necessary libraries and paths to read the "pickles" as well as store image for the graph towards the end of our code. The pickles are read and the data is fed into an DT model.
#
# Finally, we have two graphs showing the DT results vs. the fitted model as well as predicted results vs. actuals and test data

# %%
import warnings
warnings.filterwarnings('ignore')

# %run helper_functions.py
# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Create a folder for every run of the Decision tree to store our experiments

# %%
city='Houston' # New_York Atlanta Boston Dallas Houston Miami
analysis_type = 'Enhanced_Signals' # Basic, Inc_Signals, Enhanced_Signals

# %%
EXPERIMENT_DIR, EXPERIMENT_ID  = create_results_perrun()
print(f"Experiment ID: {EXPERIMENT_ID}")
print(f"Path of the results directory:{EXPERIMENT_DIR}")
# Out:
# Experiment ID: 18
# Path of the results directory:../experiment_results/RUN-18

# %% [markdown]
# Here we are importing the train and test Data from pickle files created through the EDA file

# %%
X_train = pd.read_pickle(f'{PICKLE_PATH}/X_train_{city}_{analysis_type}.pkl')
Y_train = pd.read_pickle(f'{PICKLE_PATH}/Y_train_{city}_{analysis_type}.pkl')

X_test  = pd.read_pickle(f'{PICKLE_PATH}/X_test_{city}_{analysis_type}.pkl')
Y_test  = pd.read_pickle(f'{PICKLE_PATH}/Y_test_{city}_{analysis_type}.pkl')

print("Shape of Training Dataset " , X_train.shape)
print("Shape of Testing Dataset " , X_test.shape)
# Out:
# Shape of Training Dataset  (1432, 17)
# Shape of Testing Dataset  (90, 17)

# %%
# Fitting a decision tree regressor with max depth
max_depth = 8
fitted_model = tree.DecisionTreeRegressor(max_depth=max_depth)
fitted_model.fit(X_train,Y_train)

# Dataframe to show features and their importances
top_features = len(fitted_model.feature_importances_)
features_importances_df= show_feature_importances(X_train.columns.values.tolist(),
                                                  fitted_model.feature_importances_,top_features)
features_importances_df.head(10)

# Store results
features_importances_df.to_csv(f'{EXPERIMENT_DIR}/feature_importances.csv')

# %%
# Run the model on the training dataset
Y_train_pred = fitted_model.predict(X_train)

# Calculate mean squared error for the predicted values
mse_train = mean_squared_error(Y_train, Y_train_pred)
print('Mean Squared Error for the training dataset: %.3f' % mse_train)
# Out:
# Mean Squared Error for the training dataset: 2.785

# %%
# Run the model on the testing dataset
Y_test_pred = fitted_model.predict(X_test)

# Calculate mean squared error for the test vs predicted values
mse_test = mean_squared_error(Y_test, Y_test_pred)
print('Mean Squared Error for the testing dataset: %.3f' % mse_test)
# Out:
# Mean Squared Error for the testing dataset: 10.205

# %%
# Creating a dataframe for predicted/fitted values
future_forecast = pd.DataFrame(Y_test_pred,index = Y_test.index,columns=['Fitted'])

# Concatenate the predicted/fitted values with actual values to display graphs
predictions = pd.concat([Y_test,future_forecast],axis=1)
predictions.columns = ["Actual","Fitted"]

# Displaying few of the predicted values
predictions.head(10)
# Out:
#                Actual     Fitted
# datetime
# 2017-09-02  27.658333  26.292523
# 2017-09-03  27.312917  26.292523
# 2017-09-04  27.032500  26.585889
# 2017-09-05  27.558333  26.585889
# 2017-09-06  25.762500  26.585889
# 2017-09-07  22.602917  26.585889
# 2017-09-08  22.617917  23.691244
# 2017-09-09  23.091667  23.691244
# 2017-09-10  23.897917  23.691244
# 2017-09-11  23.837500  25.365880

# %% [markdown]
# Mean Squared error (MAE), would be easier to interpret as they use the same scale as the data itself.

# %%
city = city.replace('_',' ')
# Plotting the daily predicted temperature vs Actual Temperature - Decision Tree
fig = charter_helper_fitted(f"Daily Predicted Temperature using Decision Tree for {city} using {analysis_type}", predictions)
iplot(fig)

py.image.save_as(fig, f'{EXPERIMENT_DIR}/Daily_DT_actual_vs_predict.png')
# Out:
# <div id="2287ee10-1e9e-41ce-bbb5-8e13f9bb2e4e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '2287ee10-1e9e-41ce-bbb5-8e13f9bb2e4e',
#             [{"name": "Actual", "x": ["2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-09-30", "2017-10-01", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-07", "2017-10-08", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-14", "2017-10-15", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-21", "2017-10-22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28", "2017-10-29", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-04", "2017-11-05", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-11", "2017-11-12", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-18", "2017-11-19", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-23", "2017-11-24", "2017-11-25", "2017-11-26", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30"], "y": [27.658333333333342, 27.312916666666677, 27.032500000000013, 27.55833333333335, 25.762500000000017, 22.602916666666687, 22.617916666666677, 23.091666666666686, 23.897916666666692, 23.837500000000016, 22.739166666666677, 24.556666666666683, 25.85375000000002, 26.496250000000014, 26.708750000000023, 26.60833333333335, 27.897916666666674, 27.222083333333345, 28.46916666666668, 26.216342888375024, 26.69750000000002, 27.062500000000018, 27.15125000000002, 27.097083333333348, 27.210000000000022, 27.591250000000027, 27.625635663750018, 26.547916666666694, 26.047500000000024, 25.60125000000002, 26.05625000000003, 26.565000000000015, 26.992500000000017, 26.109583333333347, 24.809583333333354, 25.137916666666694, 27.670416666666693, 27.87508374600002, 25.362083333333356, 21.89000000000002, 24.01041666666669, 26.57708333333335, 27.191125000000028, 25.98666666666669, 21.13250000000002, 18.377083333333356, 18.606666666666687, 22.477916666666687, 23.604166666666686, 25.55041666666669, 22.65333333333336, 18.281250000000025, 18.865000000000023, 16.60416666666669, 17.334583333333352, 18.895833333333357, 11.342083333333354, 11.02916666666669, 15.46375000000002, 20.199583333333354, 22.19750000000002, 25.355000000000008, 25.692500000000024, 25.13958333333335, 25.74875000000002, 26.028750000000016, 25.524166666666684, 17.710569235750015, 13.742019324333354, 14.063750000000015, 18.60032311983335, 20.09916666666669, 20.40208333333335, 19.42833333333336, 20.07632325687502, 22.630833333333356, 23.377500000000015, 23.912083333333356, 15.152500000000023, 12.296250000000017, 17.33250000000002, 17.42166666666669, 11.669583333333357, 11.970000000000018, 16.880833333333356, 18.144583333333355, 15.504583333333352, 16.50529166666669, 18.405416666666678, 18.29000000000002], "type": "scatter", "uid": "1d7db5a8-a014-11e8-b744-00215cc353c9"}, {"name": "Fitted", "x": ["2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-09-30", "2017-10-01", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-07", "2017-10-08", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-14", "2017-10-15", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-21", "2017-10-22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28", "2017-10-29", "2017-10-30", "2017-1 ...
#             {"title": "Daily Predicted Temperature using Decision Tree for Houston using Enhanced_Signals", "xaxis": {"rangeselector": {"buttons": [{"step": "all"}, {"count": 1, "label": "1m", "step": "month", "stepmode": "backward"}]}, "rangeslider": {"visible": true}, "type": "date"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('2287ee10-1e9e-41ce-bbb5-8e13f9bb2e4e',{});}).then(function(){Plotly.animate('2287ee10-1e9e-41ce-bbb5-8e13f9bb2e4e');})
#         });</script>

# %%
# Plotting the training data for past year, Actual/test data and predicted temperature - Decision Tree
fig = charter_helper_prediction(f"Daily Predicted Temperature using Decision Tree for {city} using {analysis_type}", 
                     X_train,Y_train,X_test,Y_test,future_forecast)

iplot(fig)

py.image.save_as(fig, f'{EXPERIMENT_DIR}/Daily_DT_predict.png')
# Out:
# <div id="ff0c8db0-61b8-4dc9-9b71-27be9e0266ce" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'ff0c8db0-61b8-4dc9-9b71-27be9e0266ce',
#             [{"name": "Train temperature", "x": ["2016-09-02", "2016-09-03", "2016-09-04", "2016-09-05", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-10", "2016-09-11", "2016-09-12", "2016-09-13", "2016-09-14", "2016-09-15", "2016-09-16", "2016-09-17", "2016-09-18", "2016-09-19", "2016-09-20", "2016-09-21", "2016-09-22", "2016-09-23", "2016-09-24", "2016-09-25", "2016-09-26", "2016-09-27", "2016-09-28", "2016-09-29", "2016-09-30", "2016-10-01", "2016-10-02", "2016-10-03", "2016-10-04", "2016-10-05", "2016-10-06", "2016-10-07", "2016-10-08", "2016-10-09", "2016-10-10", "2016-10-11", "2016-10-12", "2016-10-13", "2016-10-14", "2016-10-15", "2016-10-16", "2016-10-17", "2016-10-18", "2016-10-19", "2016-10-20", "2016-10-21", "2016-10-22", "2016-10-23", "2016-10-24", "2016-10-25", "2016-10-26", "2016-10-27", "2016-10-28", "2016-10-29", "2016-10-30", "2016-10-31", "2016-11-01", "2016-11-02", "2016-11-03", "2016-11-04", "2016-11-05", "2016-11-06", "2016-11-07", "2016-11-08", "2016-11-09", "2016-11-10", "2016-11-11", "2016-11-12", "2016-11-13", "2016-11-14", "2016-11-15", "2016-11-16", "2016-11-17", "2016-11-18", "2016-11-19", "2016-11-20", "2016-11-21", "2016-11-22", "2016-11-23", "2016-11-24", "2016-11-25", "2016-11-26", "2016-11-27", "2016-11-28", "2016-11-29", "2016-11-30", "2016-12-01", "2016-12-02", "2016-12-03", "2016-12-04", "2016-12-05", "2016-12-06", "2016-12-07", "2016-12-08", "2016-12-09", "2016-12-10", "2016-12-11", "2016-12-12", "2016-12-13", "2016-12-14", "2016-12-15", "2016-12-16", "2016-12-17", "2016-12-18", "2016-12-19", "2016-12-20", "2016-12-21", "2016-12-22", "2016-12-23", "2016-12-24", "2016-12-25", "2016-12-26", "2016-12-27", "2016-12-28", "2016-12-29", "2016-12-30", "2016-12-31", "2017-01-01", "2017-01-02", "2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-07", "2017-01-08", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-14", "2017-01-15", "2017-01-16", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-21", "2017-01-22", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-28", "2017-01-29", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-04", "2017-02-05", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-11", "2017-02-12", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-18", "2017-02-19", "2017-02-20", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-25", "2017-02-26", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-04", "2017-03-05", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-11", "2017-03-12", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-18", "2017-03-19", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-25", "2017-03-26", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-01", "2017-04-02", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-08", "2017-04-09", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-14", "2017-04-15", "2017-04-16", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-22", "2017-04-23", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-04-29", "2017-04-30", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-06", "2017-05-07", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-13", "2017-05-14", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-20", "2017-05-21", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-27", "2017-05-28", "2017-05-29", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-03", "2017-06-04", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-10", "20 ...

# %%
results = update_results_function(EXPERIMENT_ID, 'DECISION TREE', city, analysis_type,
                                  {'max_depth': max_depth, 'Info': X_train._metadata },
                                  {'features' : X_train.columns.values.tolist(),
                                   'importances':fitted_model.feature_importances_,
                                   'mse_train' : mse_train}, 
                                    mse_test)

# %%
results.tail(1)
# Out:
#    RUN_ID                   DATETIME     MODEL_NAME     CITY  \
# 17     18 2018-08-14 19:48:11.736850  DECISION TREE  Houston
#
#         FEATURE_TYPE     HOST_MACHINE  \
# 17  Enhanced_Signals  DESKTOP-KN40C32
#
#                                      MODEL_PARAMETERS  \
# 17  {'max_depth': 8, 'Info': {'feature_set_type': ...
#
#                                         MODEL_RESULTS  MEAN_SQUARED_ERROR
# 17  {'features': ['temperature_lag1', 'temperature...           10.205057

# %%
results = pd.read_pickle('../pickles/results.pkl')
results
# Out:
#    RUN_ID                   DATETIME     MODEL_NAME      CITY  \
# 0       1 2018-08-14 19:41:45.275297  DECISION TREE  New York
# 1       2 2018-08-14 19:42:13.654060  DECISION TREE   Atlanta
# 2       3 2018-08-14 19:42:23.328525  DECISION TREE    Boston
# 3       4 2018-08-14 19:42:30.715058  DECISION TREE    Dallas
# 4       5 2018-08-14 19:42:41.506483  DECISION TREE   Houston
# 5       6 2018-08-14 19:42:49.124681  DECISION TREE     Miami
# 6       7 2018-08-14 19:43:04.972617  DECISION TREE  New York
# 7       8 2018-08-14 19:43:12.930159  DECISION TREE   Atlanta
# 8       9 2018-08-14 19:43:20.383683  DECISION TREE    Boston
# 9      10 2018-08-14 19:43:32.825549  DECISION TREE    Dallas
# 10     11 2018-08-14 19:43:39.374706  DECISION TREE   Houston
# 11     12 2018-08-14 19:43:48.176029  DECISION TREE     Miami
# 12     13 2018-08-14 19:44:00.243495  DECISION TREE  New York
# 13     14 2018-08-14 19:44:07.609795  DECISION TREE   Atlanta
# 14     15 2018-08-14 19:44:14.731752  DECISION TREE    Boston
# 15     16 2018-08-14 19:44:20.754761  DECISION TREE    Dallas
# 16     17 2018-08-14 19:44:46.805353  DECISION TREE     Miami
# 17     18 2018-08-14 19:48:11.736850  DECISION TREE   Houston
#
#         FEATURE_TYPE     HOST_MACHINE  \
# 0              Basic  DESKTOP-KN40C32
# 1              Basic  DESKTOP-KN40C32
# 2              Basic  DESKTOP-KN40C32
# 3              Basic  DESKTOP-KN40C32
# 4              Basic  DESKTOP-KN40C32
# 5              Basic  DESKTOP-KN40C32
# 6        Inc_Signals  DESKTOP-KN40C32
# 7        Inc_Signals  DESKTOP-KN40C32
# 8        Inc_Signals  DESKTOP-KN40C32
# 9        Inc_Signals  DESKTOP-KN40C32
# 10       Inc_Signals  DESKTOP-KN40C32
# 11       Inc_Signals  DESKTOP-KN40C32
# 12  Enhanced_Signals  DESKTOP-KN40C32
# 13  Enhanced_Signals  DESKTOP-KN40C32
# 14  Enhanced_Signals  DESKTOP-KN40C32
# 15  Enhanced_Signals  DESKTOP-KN40C32
# 16  Enhanced_Signals  DESKTOP-KN40C32
# 17  Enhanced_Signals  DESKTOP-KN40C32
#
#                                      MODEL_PARAMETERS  \
# 0   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 1   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 2   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 3   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 4   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 5   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 6   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 7   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 8   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 9   {'max_depth': 8, 'Info': {'feature_set_type': ...
# 10  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 11  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 12  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 13  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 14  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 15  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 16  {'max_depth': 8, 'Info': {'feature_set_type': ...
# 17  {'max_depth': 8, 'Info': {'feature_set_type': ...
#
#                                         MODEL_RESULTS  MEAN_SQUARED_ERROR
# 0   {'features': ['temperature_lag1', 'temperature...            5.799872
# 1   {'features': ['temperature_lag1', 'temperature...            8.436149
# 2   {'features': ['temperature_lag1', 'temperature...           16.504857
# 3   {'features': ['temperature_lag1', 'temperature...           12.523335
# 4   {'features': ['temperature_lag1', 'temperature...            7.705077
# 5   {'features': ['temperature_lag1', 'temperature...            1.833555
# 6   {'features': ['temperature_lag1', 'temperature...            6.518000
# 7   {'features': ['temperature_lag1', 'temperature...            7.992946
# 8   {'features': ['temperature_lag1', 'temperature...           22.967065
# 9   {'features': ['temperature_lag1', 'temperature...           14.223161
# 10  {'features': ['temperature_lag1', 'temperature...           10.519872
# 11  {'features': ['temperature_lag1', 'temperature...            1.577366
# 12  {'features': ['temperature_lag1', 'temperature...            6.767755
# 13  {'features': ['temperature_lag1', 'temperature...            7.783687
# 14  {'features': ['temperature_lag1', 'temperature...           25.109055
# 15  {'features': ['temperature_lag1', 'temperature...           15.432839
# 16  {'features': ['temperature_lag1', 'temperature...            1.556905
# 17  {'features': ['temperature_lag1', 'temperature...           10.205057
